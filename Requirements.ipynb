# %% [markdown]
# ## What we need:
# - Data from Peter/ Simon
# - Sensors from Simon
# - Preparation of milesstones and first prasentation
# - Important: Scheduling a Meeting with Peter/ Simon if we have any questions
